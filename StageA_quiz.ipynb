# %%
import numpy as np
import pandas as pd

# %%
Food_data = pd.read_csv("C:/Users/B!/Downloads/FoodBalanceSheets_E_Africa_NOFLAG.csv", encoding = 'latin-1')

# %%
Food_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
Food_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %% [markdown]
# Perform a groupby operation on ‘Element’.  What year has the highest sum of Stock Variation?

# %%
Food_data.groupby('Element')['Element'].count()
# Out:
# Element
# Domestic supply quantity                  5295
# Export Quantity                           4403
# Fat supply quantity (g/capita/day)        5023
# Feed                                      1319
# Food                                      4941
# Food supply (kcal/capita/day)             5014
# Food supply quantity (kg/capita/yr)       4905
# Import Quantity                           5139
# Losses                                    2009
# Other uses (non-food)                     1732
# Processing                                2010
# Production                                3881
# Protein supply quantity (g/capita/day)    5023
# Residuals                                 4655
# Seed                                       762
# Stock Variation                           4232
# Total Population - Both sexes               45
# Tourist consumption                        555
# Name: Element, dtype: int64

# %% [markdown]
# What is the total number and percentage of missing data in 2014 to 3 decimal places?

# %%
Food_data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %% [markdown]
# Answer the following questions based on the African food production dataset provided by the FAO website already provided
#
# What is the total sum of Wine produced in 2015 and 2018 respectively?

# %%
Food_data.groupby(['Item', 'Y2015', 'Y2018'])['Item'].sum()
# Out:
# Item               Y2015     Y2018
# Alcohol, Non-Food  -2.0       0.0                                        Alcohol, Non-Food
#                    -1.0      -1.0                       Alcohol, Non-FoodAlcohol, Non-Food
#                     0.0      -5.0                                        Alcohol, Non-Food
#                               0.0        Alcohol, Non-FoodAlcohol, Non-FoodAlcohol, Non...
#                               1.0        Alcohol, Non-FoodAlcohol, Non-FoodAlcohol, Non...
#                                                                ...
# Yams                7296.0    7858.0                                                  Yams
#                     16136.0   17323.0                                                 Yams
#                     21000.0   23500.0                                                 Yams
#                     44678.0   49000.0                                                 Yams
# ...

# %% [markdown]
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the highest sum in 2017?

# %%
Food_data.groupby(['Y2017', 'Area'])['Area'].sum()
# Out:
# Y2017      Area
# -1582.0    Egypt                                           EgyptEgypt
# -1200.0    Mozambique                                      Mozambique
# -1159.0    Mozambique                                      Mozambique
# -865.0     United Republic of Tanzania    United Republic of Tanzania
# -860.0     United Republic of Tanzania    United Republic of Tanzania
#                                                      ...
#  96443.0   Egypt                                                Egypt
#  106400.0  Ethiopia                                          Ethiopia
#  112625.0  Nigeria                                            Nigeria
#  117702.0  Nigeria                                            Nigeria
#  190873.0  Nigeria                                            Nigeria
# Name: Area, Length: 14773, dtype: object

# %% [markdown]
# Which year had the least correlation with ‘Element Code’?

# %%
Food_data.groupby(['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']).sum()
# Out:
# C:\Users\B!\AppData\Local\Temp\ipykernel_7848\3732577960.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   Food_data.groupby(['Element Code', 'Y2014', 'Y2015', 'Y2016', 'Y2017', 'Y2018']).sum()
#                                                       Area Code  Item Code
# Element Code Y2014   Y2015   Y2016   Y2017   Y2018
# 511          196.0   199.0   203.0   207.0   211.0          193       2501
#              518.0   525.0   531.0   537.0   544.0           35       2501
#              899.0   914.0   929.0   944.0   959.0           72       2501
#              1095.0  1104.0  1114.0  1125.0  1136.0         209       2501
#              1257.0  1259.0  1262.0  1264.0  1267.0         137       2501
# ...                                                         ...        ...
# ...

# %% [markdown]
# What is the mean and standard deviation across the whole dataset for the year 2017 to 2 decimal places?

# %%
Food_data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %% [markdown]
# Select columns ‘Y2017’ and ‘Area’, Perform a groupby operation on ‘Area’.  Which of these Areas had the 7th lowest sum in 2017?

# %%
Food_data.groupby(['Y2017', 'Area'])['Area'].min()
# Out:
# Y2017      Area
# -1582.0    Egypt                                                Egypt
# -1200.0    Mozambique                                      Mozambique
# -1159.0    Mozambique                                      Mozambique
# -865.0     United Republic of Tanzania    United Republic of Tanzania
# -860.0     United Republic of Tanzania    United Republic of Tanzania
#                                                      ...
#  96443.0   Egypt                                                Egypt
#  106400.0  Ethiopia                                          Ethiopia
#  112625.0  Nigeria                                            Nigeria
#  117702.0  Nigeria                                            Nigeria
#  190873.0  Nigeria                                            Nigeria
# Name: Area, Length: 14773, dtype: object

# %% [markdown]
# Perform a groupby operation on ‘Element’.  What is the total number of the sum of Processing in 2017?

# %%
Food_data.groupby(['Element', 'Y2017'])['Element'].sum()
# Out:
# Element                   Y2017
# Domestic supply quantity  -144.0                             Domestic supply quantity
#                           -140.0                             Domestic supply quantity
#                           -101.0     Domestic supply quantityDomestic supply quantity
#                           -84.0      Domestic supply quantityDomestic supply quantity
#                           -65.0                              Domestic supply quantity
#                                                           ...
# Tourist consumption        1.0      Tourist consumptionTourist consumptionTourist ...
#                            2.0      Tourist consumptionTourist consumptionTourist ...
#                            3.0      Tourist consumptionTourist consumptionTourist ...
#                            4.0      Tourist consumptionTourist consumptionTourist ...
#                            6.0                 Tourist consumptionTourist consumption
# ...
